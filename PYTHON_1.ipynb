# %%
import random

def choose_word():
    words = ['python', 'hangman', 'programming', 'challenge', 'artificial', 'intelligence']
    return random.choice(words)

def display_hangman(tries):
    stages = [
        """
           -----
           |   |
           O   |
          /|\\  |
          / \\  |
              ===
        """,
        """
           -----
           |   |
           O   |
          /|\\  |
          /    |
              ===
        """,
        """
           -----
           |   |
           O   |
          /|\\  |
               |
              ===
        """,
        """
           -----
           |   |
           O   |
          /|   |
               |
              ===
        """,
        """
           -----
           |   |
           O   |
           |   |
               |
              ===
        """,
        """
           -----
           |   |
           O   |
               |
               |
              ===
        """,
        """
           -----
           |   |
               |
               |
               |
              ===
        """
    ]
    return stages[6 - tries]

def play_game():
    word = choose_word()
    word_letters = set(word)
    guessed_letters = set()
    tries = 6

    print("Welcome to Hangman!")

    while tries > 0 and word_letters:
        print(display_hangman(tries))
        print("Word: ", ' '.join([letter if letter in guessed_letters else '_' for letter in word]))
        print("Guessed letters: ", ' '.join(sorted(guessed_letters)))
        guess = input("Guess a letter: ").lower()

        if len(guess) != 1 or not guess.isalpha():
            print("Invalid input. Please enter a single letter.")
            continue

        if guess in guessed_letters:
            print("You already guessed that letter.")
            continue

        guessed_letters.add(guess)

        if guess in word_letters:
            word_letters.remove(guess)
            print("Correct!")
        else:
            tries -= 1
            print("Wrong guess!")

    if not word_letters:
        print(f"Congratulations! You guessed the word '{word}' correctly!")
    else:
        print(display_hangman(tries))
        print(f"Game Over! The word was '{word}'.")

if __name__ == "__main__":
    play_game()
# Out:
# Welcome to Hangman!
#
#            -----
#            |   |
#            O   |
#           /|\  |
#           / \  |
#               ===
#
# Word:  _ _ _ _ _ _ _ _ _ _
# Guessed letters:
# Guess a letter: a
# Correct!
#
#            -----
#            |   |
#            O   |
#           /|\  |
#           / \  |
#               ===
#
# Word:  a _ _ _ _ _ _ _ a _
# Guessed letters:  a
# Guess a letter: r
# Correct!
#
#            -----
#            |   |
#            O   |
#           /|\  |
#           / \  |
#               ===
#
# Word:  a r _ _ _ _ _ _ a _
# Guessed letters:  a r
# Guess a letter: t
# Correct!
#
#            -----
#            |   |
#            O   |
#           /|\  |
#           / \  |
#               ===
#
# Word:  a r t _ _ _ _ _ a _
# Guessed letters:  a r t
# Guess a letter: i
# Correct!
#
#            -----
#            |   |
#            O   |
#           /|\  |
#           / \  |
#               ===
#
# Word:  a r t i _ i _ i a _
# Guessed letters:  a i r t
# Guess a letter: f
# Correct!
#
#            -----
#            |   |
#            O   |
#           /|\  |
#           / \  |
#               ===
#
# Word:  a r t i f i _ i a _
# Guessed letters:  a f i r t
# Guess a letter: c
# Correct!
#
#            -----
#            |   |
#            O   |
#           /|\  |
#           / \  |
#               ===
#
# Word:  a r t i f i c i a _
# Guessed letters:  a c f i r t
# Guess a letter: l
# Correct!
# Congratulations! You guessed the word 'artificial' correctly!
